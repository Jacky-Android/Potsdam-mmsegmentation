# %%
# !pip install -v -e .
# Out:
# Using pip 22.2.2 from /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages/pip (python 3.7)
# Looking in indexes: https://pypi.doubanio.com/simple
# Obtaining file:///home/rongjian/yolov7-main/wandb/mmsegmentation-master
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-b1g5b7nn/mmsegmentation.egg-info
#   writing /tmp/pip-pip-egg-info-b1g5b7nn/mmsegmentation.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-b1g5b7nn/mmsegmentation.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-pip-egg-info-b1g5b7nn/mmsegmentation.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-b1g5b7nn/mmsegmentation.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-b1g5b7nn/mmsegmentation.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-pip-egg-info-b1g5b7nn/mmsegmentation.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching 'mmseg/.mim/model-index.yml'
#   warning: no files found matching '*.py' under directory 'mmseg/.mim/configs'
#   warning: no files found matching '*.yml' under directory 'mmseg/.mim/configs'
#   warning: no files found matching '*.py' under directory 'mmseg/.mim/tools'
#   warning: no files found matching '*.sh' under directory 'mmseg/.mim/tools'
#   adding license file 'LICENSE'
#   adding license file 'LICENSES.md'
#   writing manifest file '/tmp/pip-pip-egg-info-b1g5b7nn/mmsegmentation.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from mmsegmentation==0.29.1) (3.5.3)
# Requirement already satisfied: mmcls>=0.20.1 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from mmsegmentation==0.29.1) (0.24.0)
# Requirement already satisfied: numpy in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from mmsegmentation==0.29.1) (1.21.6)
# Requirement already satisfied: packaging in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from mmsegmentation==0.29.1) (21.3)
# Requirement already satisfied: prettytable in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from mmsegmentation==0.29.1) (3.4.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from matplotlib->mmsegmentation==0.29.1) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from matplotlib->mmsegmentation==0.29.1) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from matplotlib->mmsegmentation==0.29.1) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from matplotlib->mmsegmentation==0.29.1) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from matplotlib->mmsegmentation==0.29.1) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from matplotlib->mmsegmentation==0.29.1) (9.2.0)
# Requirement already satisfied: importlib-metadata in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from prettytable->mmsegmentation==0.29.1) (5.0.0)
# Requirement already satisfied: wcwidth in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from prettytable->mmsegmentation==0.29.1) (0.2.5)
# Requirement already satisfied: typing-extensions in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib->mmsegmentation==0.29.1) (4.4.0)
# Requirement already satisfied: six>=1.5 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib->mmsegmentation==0.29.1) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from importlib-metadata->prettytable->mmsegmentation==0.29.1) (3.9.0)
# Installing collected packages: mmsegmentation
#   Running setup.py develop for mmsegmentation
#     Running command python setup.py develop
#     running develop
#     running egg_info
#     creating mmsegmentation.egg-info
#     writing mmsegmentation.egg-info/PKG-INFO
#     writing dependency_links to mmsegmentation.egg-info/dependency_links.txt
#     writing requirements to mmsegmentation.egg-info/requires.txt
#     writing top-level names to mmsegmentation.egg-info/top_level.txt
#     writing manifest file 'mmsegmentation.egg-info/SOURCES.txt'
#     reading manifest file 'mmsegmentation.egg-info/SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     adding license file 'LICENSE'
#     adding license file 'LICENSES.md'
#     writing manifest file 'mmsegmentation.egg-info/SOURCES.txt'
#     running build_ext
#     Creating /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages/mmsegmentation.egg-link (link to .)
#     Adding mmsegmentation 0.29.1 to easy-install.pth file
#
#     Installed /home/rongjian/yolov7-main/wandb/mmsegmentation-master
#     /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages/setuptools/command/easy_install.py:147: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#       EasyInstallDeprecationWarning,
#     /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages/setuptools/command/install.py:37: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       setuptools.SetuptoolsDeprecationWarning,
# Successfully installed mmsegmentation-0.29.1

# %%
# !ls
# Out:
# 2_Ortho_RGB.zip		      run-20221025_094211-1tc29ghh
# 5_Labels_all_noBoundary.zip   run-20221025_094531-13er0vjk
# debug-cli.rongjian.log	      run-20221030_191504-ap4xogg2
# debug-internal.log	      run-20221030_191523-1f9dxng3
# debug.log		      run-20221030_191812-163sf48n
# latest-run		      run-20221030_191859-2hjiyblz
# mmsegmentation-master	      Untitled.ipynb
# run-20221025_094107-3kmhx2w7

# %%
# %cd mmsegmentation-master
# Out:
# /home/rongjian/yolov7-main/wandb/mmsegmentation-master

# %%
# %%writefile tools/convert_datasets/potsdam.py
# Copyright (c) OpenMMLab. All rights reserved.
import argparse
import glob
import math
import os
import os.path as osp
import tempfile
import zipfile

import mmcv
import numpy as np


def parse_args():
    parser = argparse.ArgumentParser(
        description='Convert potsdam dataset to mmsegmentation format')
    parser.add_argument('dataset_path', help='potsdam folder path')
    parser.add_argument('--tmp_dir', help='path of the temporary directory')
    parser.add_argument('-o', '--out_dir', help='output path')
    parser.add_argument(
        '--clip_size',
        type=int,
        help='clipped size of image after preparation',
        default=512)
    parser.add_argument(
        '--stride_size',
        type=int,
        help='stride of clipping original images',
        default=256)
    args = parser.parse_args()
    return args


def clip_big_image(image_path, clip_save_dir, args, to_label=False):
    # Original image of Potsdam dataset is very large, thus pre-processing
    # of them is adopted. Given fixed clip size and stride size to generate
    # clipped image, the intersection　of width and height is determined.
    # For example, given one 5120 x 5120 original image, the clip size is
    # 512 and stride size is 256, thus it would generate 20x20 = 400 images
    # whose size are all 512x512.
    image = mmcv.imread(image_path)

    h, w, c = image.shape
    clip_size = args.clip_size
    stride_size = args.stride_size

    num_rows = math.ceil((h - clip_size) / stride_size) if math.ceil(
        (h - clip_size) /
        stride_size) * stride_size + clip_size >= h else math.ceil(
            (h - clip_size) / stride_size) + 1
    num_cols = math.ceil((w - clip_size) / stride_size) if math.ceil(
        (w - clip_size) /
        stride_size) * stride_size + clip_size >= w else math.ceil(
            (w - clip_size) / stride_size) + 1

    x, y = np.meshgrid(np.arange(num_cols + 1), np.arange(num_rows + 1))
    xmin = x * clip_size
    ymin = y * clip_size

    xmin = xmin.ravel()
    ymin = ymin.ravel()
    xmin_offset = np.where(xmin + clip_size > w, w - xmin - clip_size,
                           np.zeros_like(xmin))
    ymin_offset = np.where(ymin + clip_size > h, h - ymin - clip_size,
                           np.zeros_like(ymin))
    boxes = np.stack([
        xmin + xmin_offset, ymin + ymin_offset,
        np.minimum(xmin + clip_size, w),
        np.minimum(ymin + clip_size, h)
    ],
                     axis=1)

    if to_label:
        color_map = np.array([[255, 255, 255], [0, 0, 255], [0, 255, 255], [0, 255, 0],[255, 255, 0], [255, 0, 0]])
        flatten_v = np.matmul(
            image.reshape(-1, c),
            np.array([2, 3, 4]).reshape(3, 1))
        out = np.zeros_like(flatten_v)
        for idx, class_color in enumerate(color_map):
            value_idx = np.matmul(class_color,
                                  np.array([2, 3, 4]).reshape(3, 1))
            out[flatten_v == value_idx] = idx
        image = out.reshape(h, w)

    for box in boxes:
        start_x, start_y, end_x, end_y = box
        clipped_image = image[start_y:end_y,
                              start_x:end_x] if to_label else image[
                                  start_y:end_y, start_x:end_x, :]
        idx_i, idx_j = osp.basename(image_path).split('_')[2:4]
        mmcv.imwrite(
            clipped_image.astype(np.uint8),
            osp.join(
                clip_save_dir,
                f'{idx_i}_{idx_j}_{start_x}_{start_y}_{end_x}_{end_y}.png'))


def main():
    args = parse_args()
    splits = {
        'train': [
            '2_10', '2_11', '2_12', '3_10', '3_11', '3_12', '4_10', '4_11',
            '4_12', '5_10', '5_11', '5_12', '6_10', '6_11', '6_12', '6_7',
            '6_8', '6_9', '7_10', '7_11', '7_12', '7_7', '7_8', '7_9'
        ],
        'val': [
            '5_15', '6_15', '6_13', '3_13', '4_14', '6_14', '5_14', '2_13',
            '4_15', '2_14', '5_13', '4_13', '3_14', '7_13'
        ]
    }

    dataset_path = args.dataset_path
    if args.out_dir is None:
        out_dir = osp.join('data', 'potsdam')
    else:
        out_dir = args.out_dir

    print('Making directories...')
    mmcv.mkdir_or_exist(osp.join(out_dir, 'img_dir', 'train'))
    mmcv.mkdir_or_exist(osp.join(out_dir, 'img_dir', 'val'))
    mmcv.mkdir_or_exist(osp.join(out_dir, 'ann_dir', 'train'))
    mmcv.mkdir_or_exist(osp.join(out_dir, 'ann_dir', 'val'))

    zipp_list = glob.glob(os.path.join(dataset_path, '*.zip'))
    print('Find the data', zipp_list)

    for zipp in zipp_list:
        with tempfile.TemporaryDirectory(dir=args.tmp_dir) as tmp_dir:
            zip_file = zipfile.ZipFile(zipp)
            zip_file.extractall(tmp_dir)
            src_path_list = glob.glob(os.path.join(tmp_dir, '*.tif'))
            if not len(src_path_list):
                sub_tmp_dir = os.path.join(tmp_dir, os.listdir(tmp_dir)[0])
                src_path_list = glob.glob(os.path.join(sub_tmp_dir, '*.tif'))

            prog_bar = mmcv.ProgressBar(len(src_path_list))
            for i, src_path in enumerate(src_path_list):
                idx_i, idx_j = osp.basename(src_path).split('_')[2:4]
                data_type = 'train' if f'{idx_i}_{idx_j}' in splits[
                    'train'] else 'val'
                if 'label' in src_path:
                    dst_dir = osp.join(out_dir, 'ann_dir', data_type)
                    clip_big_image(src_path, dst_dir, args, to_label=True)
                else:
                    dst_dir = osp.join(out_dir, 'img_dir', data_type)
                    clip_big_image(src_path, dst_dir, args, to_label=False)
                prog_bar.update()

    print('Removing the temporary files...')

    print('Done!')


if __name__ == '__main__':
    main()
# Out:
# Overwriting tools/convert_datasets/potsdam.py

# %%
# !python tools/convert_datasets/potsdam.py /home/rongjian/yolov7-main/wandb  -o /home/rongjian/yolov7-main/wandb --tmp_dir /home/rongjian/yolov7-main/wandb/tmp
# Out:
# Making directories...
# Find the data ['/home/rongjian/yolov7-main/wandb/2_Ortho_RGB.zip', '/home/rongjian/yolov7-main/wandb/5_Labels_all_noBoundary.zip']
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 38/38, 0.3 task/s, elapsed: 129s, ETA:     0s[                                                  ] 0/38, elapsed: 0s, ETA:Removing the temporary files...
# Done!

# %%
# %%writefile configs/_base_/models/danet_r50-d8.py
norm_cfg = dict(type='SyncBN', requires_grad=True)
model = dict(
    type='EncoderDecoder',
    pretrained='open-mmlab://resnet50_v1c',
    backbone=dict(
        type='ResNetV1c',
        depth=50,
        num_stages=4,
        out_indices=(0, 1, 2, 3),
        dilations=(1, 1, 2, 4),
        strides=(1, 2, 1, 1),
        norm_cfg=norm_cfg,
        norm_eval=False,
        style='pytorch',
        contract_dilation=True),
    decode_head=dict(
        type='PSPHead',
        in_channels=2048,
        in_index=3,
        channels=512,
        pool_scales=(1, 2, 3, 6),
        dropout_ratio=0.1,
        num_classes=6,
        norm_cfg=norm_cfg,
        align_corners=False,
        loss_decode=dict(
            type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0)),
    auxiliary_head=dict(
        type='FCNHead',
        in_channels=1024,
        in_index=2,
        channels=256,
        num_convs=1,
        concat_input=False,
        dropout_ratio=0.1,
        num_classes=6,
        norm_cfg=norm_cfg,
        align_corners=False,
        loss_decode=dict(
            type='CrossEntropyLoss', use_sigmoid=False, loss_weight=0.4)),
    # model training and testing settings
    train_cfg=dict(),
    test_cfg=dict(mode='whole'))
# Out:
# Overwriting configs/_base_/models/danet_r50-d8.py

# %%
# %%writefile mmseg/datasets/my_dataset.py
import mmcv
from mmcv.utils import print_log

from ..utils import get_root_logger
from .builder import DATASETS
from .custom import CustomDataset
import os.path as osp


from .builder import DATASETS
from .custom import CustomDataset


@DATASETS.register_module()
class Mydataset(CustomDataset):
    """ISPRS Potsdam dataset.
    In segmentation map annotation for Potsdam dataset, 0 is the ignore index.
    ``reduce_zero_label`` should be set to True. The ``img_suffix`` and
    ``seg_map_suffix`` are both fixed to '.png'.
    """
    CLASSES = ('impervious_surface', 'building', 'low_vegetation', 'tree','car', 'clutter')

    PALETTE = [[255, 255, 255], [0, 0, 255], [0, 255, 255], [0, 255, 0],[255, 255, 0], [255, 0, 0]]

    def __init__(self, **kwargs):
        super(Mydataset, self).__init__(
            img_suffix='.png',
            seg_map_suffix='.png',
            reduce_zero_label=True,
            **kwargs)
# Out:
# Overwriting mmseg/datasets/my_dataset.py

# %%
# %%writefile configs/_base_/datasets/my_dataset.py
dataset_type = 'Mydataset' #上一步中你定义的数据集的名字


data_root = '/home/rongjian/yolov7-main/wandb'
img_norm_cfg = dict(
    mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
crop_size = (512,512)
train_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='LoadAnnotations', reduce_zero_label=True),
    dict(type='Resize', img_scale=(512,512), ratio_range=(0.5, 2.0)),
    dict(type='RandomCrop', crop_size=crop_size, cat_max_ratio=0.75),
    dict(type='RandomFlip', prob=0.5),
    dict(type='PhotoMetricDistortion'),
    dict(type='Normalize', **img_norm_cfg),
    dict(type='Pad', size=crop_size, pad_val=0, seg_pad_val=255),
    dict(type='DefaultFormatBundle'),
    dict(type='Collect', keys=['img', 'gt_semantic_seg']),
]
test_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(
        type='MultiScaleFlipAug',
        img_scale=(512,512),
        # img_ratios=[0.5, 0.75, 1.0, 1.25, 1.5, 1.75],
        flip=False,
        transforms=[
            dict(type='Resize', keep_ratio=True),
            dict(type='RandomFlip'),
            dict(type='Normalize', **img_norm_cfg),
            dict(type='ImageToTensor', keys=['img']),
            dict(type='Collect', keys=['img']),
        ])
]
data = dict(
    samples_per_gpu=8,
    workers_per_gpu=8,
    train=dict(
        type=dataset_type,
        data_root=data_root,
        img_dir='img_dir/train',
        ann_dir='ann_dir/train',
        pipeline=train_pipeline),
    val=dict(
        type=dataset_type,
        data_root=data_root,
        img_dir='img_dir/val',
        ann_dir='ann_dir/val',
        pipeline=test_pipeline),
    test=dict(
        type=dataset_type,
        data_root=data_root,
        img_dir='img_dir/val',
        ann_dir='ann_dir/val',
        pipeline=test_pipeline))
# Out:
# Overwriting configs/_base_/datasets/my_dataset.py

# %%
# %%writefile mmseg/datasets/__init__.py
from .ade import ADE20KDataset
from .builder import DATASETS, PIPELINES, build_dataloader, build_dataset
from .chase_db1 import ChaseDB1Dataset
from .cityscapes import CityscapesDataset
from .coco_stuff import COCOStuffDataset
from .custom import CustomDataset
from .dark_zurich import DarkZurichDataset
from .dataset_wrappers import (ConcatDataset, MultiImageMixDataset,
                               RepeatDataset)
from .drive import DRIVEDataset
from .hrf import HRFDataset
from .isaid import iSAIDDataset
from .isprs import ISPRSDataset
from .loveda import LoveDADataset
from .night_driving import NightDrivingDataset
from .pascal_context import PascalContextDataset, PascalContextDataset59
from .potsdam import PotsdamDataset
from .stare import STAREDataset
from .voc import PascalVOCDataset
import sys
sys.path.append('..')
from .my_dataset import Mydataset
__all__ = [
    'CustomDataset', 'build_dataloader', 'ConcatDataset', 'RepeatDataset',
    'DATASETS', 'build_dataset', 'PIPELINES', 'CityscapesDataset',
    'PascalVOCDataset', 'ADE20KDataset', 'PascalContextDataset',
    'PascalContextDataset59', 'ChaseDB1Dataset', 'DRIVEDataset', 'HRFDataset',
    'STAREDataset', 'DarkZurichDataset', 'NightDrivingDataset',
    'COCOStuffDataset', 'LoveDADataset', 'MultiImageMixDataset',
    'iSAIDDataset', 'ISPRSDataset', 'PotsdamDataset','Mydataset'
]
# Out:
# Overwriting mmseg/datasets/__init__.py

# %%
# %%writefile configs/_base_/schedules/schedule_20k.py
optimizer = dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005)
optimizer_config = dict()
# learning policy
lr_config = dict(policy='poly', power=0.9, min_lr=1e-4, by_epoch=False)
runner = dict(type='EpochBasedRunner', max_epochs=10) #按epoch的方式进行迭代
checkpoint_config = dict(by_epoch=True, interval=5) #每多少次迭代保存一次模型
evaluation = dict(interval=1 ,metric='mIoU')
# Out:
# Overwriting configs/_base_/schedules/schedule_20k.py

# %%
# %%writefile configs/pspnet/pspnet_r50-d8_512x512_160k_ade20k.py 
_base_ = [
    '../_base_/models/danet_r50-d8.py', '../_base_/datasets/my_dataset.py',
    '../_base_/default_runtime.py', '../_base_/schedules/schedule_20k.py'
]
model = dict(
    decode_head=dict(num_classes=6), auxiliary_head=dict(num_classes=6))
# Out:
# Overwriting configs/pspnet/pspnet_r50-d8_512x512_160k_ade20k.py

# %%
# !python tools/train.py configs/pspnet/pspnet_r50-d8_512x512_160k_ade20k.py
# Out:
# 2022-11-05 15:38:30,403 - mmseg - INFO - Multi-processing start method is `None`
# 2022-11-05 15:38:30,403 - mmseg - INFO - OpenCV num_threads is `32
# fatal: not a git repository (or any parent up to mount point /)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2022-11-05 15:38:30,430 - mmseg - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.13 (default, Oct 18 2022, 18:57:03) [GCC 11.2.0]
# CUDA available: True
# GPU 0: NVIDIA GeForce RTX 3090
# CUDA_HOME: /usr/local/cuda
# NVCC: Cuda compilation tools, release 11.6, V11.6.124
# GCC: gcc (GCC) 8.5.0 20210514 (Red Hat 8.5.0-10)
# PyTorch: 1.12.1+cu116
# PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.3.2  (built against CUDA 11.5)
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.6, CUDNN_VERSION=8.3.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.12.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=OFF, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
# TorchVision: 0.13.1+cu116
# OpenCV: 4.6.0
# MMCV: 1.6.2
# MMCV Compiler: GCC 9.3
# MMCV CUDA Compiler: 11.6
# MMSegmentation: 0.29.1+
# ------------------------------------------------------------
#
# 2022-11-05 15:38:30,430 - mmseg - INFO - Distributed training: False
# 2022-11-05 15:38:30,784 - mmseg - INFO - Config:
# norm_cfg = dict(type='SyncBN', requires_grad=True)
# model = dict(
#     type='EncoderDecoder',
#     pretrained='open-mmlab://resnet50_v1c',
#     backbone=dict(
#         type='ResNetV1c',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         dilations=(1, 1, 2, 4),
#         strides=(1, 2, 1, 1),
#         norm_cfg=dict(type='SyncBN', requires_grad=True),
#         norm_eval=False,
#         style='pytorch',
#         contract_dilation=True),
#     decode_head=dict(
#         type='PSPHead',
#         in_channels=2048,
#         in_index=3,
#         channels=512,
#         pool_scales=(1, 2, 3, 6),
#         dropout_ratio=0.1,
#         num_classes=6,
#         norm_cfg=dict(type='SyncBN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0)),
#     auxiliary_head=dict(
#         type='FCNHead',
#         in_channels=1024,
#         in_index=2,
#         channels=256,
#         num_convs=1,
#         concat_input=False,
#         dropout_ratio=0.1,
#         num_classes=6,
#         norm_cfg=dict(type='SyncBN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=0.4)),
#     train_cfg=dict(),
#     test_cfg=dict(mode='whole'))
# dataset_type = 'Mydataset'
# data_root = '/home/rongjian/yolov7-main/wandb'
# img_norm_cfg = dict(
#     mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
# crop_size = (512, 512)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', reduce_zero_label=True),
#     dict(type='Resize', img_scale=(512, 512), ratio_range=(0.5, 2.0)),
#     dict(type='RandomCrop', crop_size=(512, 512), cat_max_ratio=0.75),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PhotoMetricDistortion'),
#     dict(
#         type='Normalize',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         to_rgb=True),
#     dict(type='Pad', size=(512, 512), pad_val=0, seg_pad_val=255),
#     dict(type='DefaultFormatBundle'),
#     dict(type='Collect', keys=['img', 'gt_semantic_seg'])
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='MultiScaleFlipAug',
#         img_scale=(512, 512),
#         flip=False,
#         transforms=[
#             dict(type='Resize', keep_ratio=True),
#             dict(type='RandomFlip'),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='ImageToTensor', keys=['img']),
#             dict(type='Collect', keys=['img'])
#         ])
# ]
# data = dict(
#     samples_per_gpu=8,
#     workers_per_gpu=8,
#     train=dict(
#         type='Mydataset',
#         data_root='/home/rongjian/yolov7-main/wandb',
#         img_dir='img_dir/train',
#         ann_dir='ann_dir/train',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', reduce_zero_label=True),
#             dict(type='Resize', img_scale=(512, 512), ratio_range=(0.5, 2.0)),
#             dict(type='RandomCrop', crop_size=(512, 512), cat_max_ratio=0.75),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PhotoMetricDistortion'),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size=(512, 512), pad_val=0, seg_pad_val=255),
#             dict(type='DefaultFormatBundle'),
#             dict(type='Collect', keys=['img', 'gt_semantic_seg'])
#         ]),
#     val=dict(
#         type='Mydataset',
#         data_root='/home/rongjian/yolov7-main/wandb',
#         img_dir='img_dir/val',
#         ann_dir='ann_dir/val',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(512, 512),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]),
#     test=dict(
#         type='Mydataset',
#         data_root='/home/rongjian/yolov7-main/wandb',
#         img_dir='img_dir/val',
#         ann_dir='ann_dir/val',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(512, 512),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]))
# log_config = dict(
#     interval=50, hooks=[dict(type='TextLoggerHook', by_epoch=False)])
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = None
# resume_from = None
# workflow = [('train', 1)]
# cudnn_benchmark = True
# optimizer = dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005)
# optimizer_config = dict()
# lr_config = dict(policy='poly', power=0.9, min_lr=0.0001, by_epoch=False)
# runner = dict(type='EpochBasedRunner', max_epochs=10)
# checkpoint_config = dict(by_epoch=True, interval=5)
# evaluation = dict(interval=1, metric='mIoU')
# work_dir = './work_dirs/pspnet_r50-d8_512x512_160k_ade20k'
# gpu_ids = [0]
# auto_resume = False
#
# 2022-11-05 15:38:30,786 - mmseg - INFO - Set random seed to 720406993, deterministic: False
# /home/rongjian/yolov7-main/wandb/mmsegmentation-master/mmseg/models/backbones/resnet.py:431: UserWarning: DeprecationWarning: pretrained is a deprecated, please use "init_cfg" instead
#   warnings.warn('DeprecationWarning: pretrained is a deprecated, '
# /home/rongjian/yolov7-main/wandb/mmsegmentation-master/mmseg/models/losses/cross_entropy_loss.py:236: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   'Default ``avg_non_ignore`` is False, if you would like to '
# 2022-11-05 15:38:31,256 - mmseg - INFO - initialize ResNetV1c with init_cfg {'type': 'Pretrained', 'checkpoint': 'open-mmlab://resnet50_v1c'}
# 2022-11-05 15:38:31,256 - mmcv - INFO - load model from: open-mmlab://resnet50_v1c
# 2022-11-05 15:38:31,257 - mmcv - INFO - load checkpoint from openmmlab path: open-mmlab://resnet50_v1c
# 2022-11-05 15:38:31,336 - mmcv - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 2022-11-05 15:38:31,349 - mmseg - INFO - initialize PSPHead with init_cfg {'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
# 2022-11-05 15:38:31,468 - mmseg - INFO - initialize FCNHead with init_cfg {'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
# tools/train.py:207: UserWarning: SyncBN is only supported with DDP. To be compatible with DP, we convert SyncBN to BN. Please use dist_train.sh which can avoid this error.
#   'SyncBN is only supported with DDP. To be compatible with DP, '
# 2022-11-05 15:38:31,496 - mmseg - INFO - EncoderDecoder(
#   (backbone): ResNetV1c(
#     (stem): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): _BatchNormXd(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): _BatchNormXd(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#       (6): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (7): _BatchNormXd(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU(inplace=True)
#     )
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): _BatchNormXd(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): _BatchNormXd(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): _BatchNormXd(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): _BatchNormXd(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): _BatchNormXd(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Pretrained', 'checkpoint': 'open-mmlab://resnet50_v1c'}
#   (decode_head): PSPHead(
#     input_transform=None, ignore_index=255, align_corners=False
#     (loss_decode): CrossEntropyLoss(avg_non_ignore=False)
#     (conv_seg): Conv2d(512, 6, kernel_size=(1, 1), stride=(1, 1))
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (psp_modules): PPM(
#       (0): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): ConvModule(
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#       (1): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=2)
#         (1): ConvModule(
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#       (2): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=3)
#         (1): ConvModule(
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#       (3): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=6)
#         (1): ConvModule(
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#     )
#     (bottleneck): ConvModule(
#       (conv): Conv2d(4096, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activate): ReLU(inplace=True)
#     )
#   )
#   init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
#   (auxiliary_head): FCNHead(
#     input_transform=None, ignore_index=255, align_corners=False
#     (loss_decode): CrossEntropyLoss(avg_non_ignore=False)
#     (conv_seg): Conv2d(256, 6, kernel_size=(1, 1), stride=(1, 1))
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (convs): Sequential(
#       (0): ConvModule(
#         (conv): Conv2d(1024, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
# )
# 2022-11-05 15:38:31,574 - mmseg - INFO - Loaded 3456 images
# fatal: not a git repository (or any parent up to mount point /)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2022-11-05 15:38:33,168 - mmseg - INFO - Loaded 2016 images
# 2022-11-05 15:38:33,169 - mmseg - INFO - Start running, host: rongjian@rtx3090, work_dir: /home/rongjian/yolov7-main/wandb/mmsegmentation-master/work_dirs/pspnet_r50-d8_512x512_160k_ade20k
# 2022-11-05 15:38:33,169 - mmseg - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) PolyLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) PolyLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) PolyLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_epoch:
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# 2022-11-05 15:46:55,223 - mmseg - INFO - Iter [800/4320]	lr: 8.336e-03, eta: 0:31:42, time: 0.524, data_time: 0.006, memory: 13224, decode.loss_ce: 0.3545, decode.acc_seg: 83.0034, aux.loss_ce: 0.1813, aux.acc_seg: 78.9023, loss: 0.5357
# 2022-11-05 15:47:21,347 - mmseg - INFO - Iter [850/4320]	lr: 8.230e-03, eta: 0:31:12, time: 0.522, data_time: 0.006, memory: 13224, decode.loss_ce: 0.3743, decode.acc_seg: 83.1454, aux.loss_ce: 0.1944, aux.acc_seg: 78.2821, loss: 0.5687
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>] 2016/2016, 36.7 task/s, elapsed: 55s, ETA:     0s2022-11-05 15:48:37,032 - mmseg - INFO - per class results:
# 2022-11-05 15:48:37,036 - mmseg - INFO -
# +--------------------+-------+-------+
# |       Class        |  IoU  |  Acc  |
# +--------------------+-------+-------+
# | impervious_surface | 70.78 | 92.28 |
# |      building      | 86.68 | 94.88 |
# |   low_vegetation   | 54.48 | 65.43 |
# |        tree        | 68.07 | 75.65 |
# |        car         | 83.97 |  93.1 |
# |      clutter       | 24.03 | 25.23 |
# +--------------------+-------+-------+
# 2022-11-05 15:48:37,037 - mmseg - INFO - Summary:
# 2022-11-05 15:48:37,039 - mmseg - INFO -
# +-------+-------+-------+
# |  aAcc |  mIoU |  mAcc |
# +-------+-------+-------+
# | 81.66 | 64.67 | 74.43 |
# +-------+-------+-------+
# 2022-11-05 15:48:37,040 - mmseg - INFO - Iter(val) [2016]	aAcc: 0.8166, mIoU: 0.6467, mAcc: 0.7443, IoU.impervious_surface: 0.7078, IoU.building: 0.8668, IoU.low_vegetation: 0.5448, IoU.tree: 0.6807, IoU.car: 0.8397, IoU.clutter: 0.2403, Acc.impervious_surface: 0.9228, Acc.building: 0.9488, Acc.low_vegetation: 0.6543, Acc.tree: 0.7565, Acc.car: 0.9310, Acc.clutter: 0.2523
# 2022-11-05 15:48:59,021 - mmseg - INFO - Iter [900/4320]	lr: 8.125e-03, eta: 0:30:58, time: 0.609, data_time: 0.076, memory: 13224, decode.loss_ce: 0.3717, decode.acc_seg: 82.5482, aux.loss_ce: 0.1924, aux.acc_seg: 77.6842, loss: 0.5641
# 2022-11-05 15:49:25,160 - mmseg - INFO - Iter [950/4320]	lr: 8.019e-03, eta: 0:30:27, time: 0.523, data_time: 0.005, memory: 13224, decode.loss_ce: 0.3652, decode.acc_seg: 82.9243, aux.loss_ce: 0.1871, aux.acc_seg: 78.7387, loss: 0.5523
# 2022-11-05 15:49:51,279 - mmseg - INFO - Exp name: pspnet_r50-d8_512x512_160k_ade20k.py
# 2022-11-05 15:49:51,281 - mmseg - INFO - Iter [1000/4320]	lr: 7.913e-03, eta: 0:29:57, time: 0.522, data_time: 0.007, memory: 13224, decode.loss_ce: 0.3682, decode.acc_seg: 83.8635, aux.loss_ce: 0.1882, aux.acc_seg: 78.3282, loss: 0.5565
# 2022-11-05 15:50:17,916 - mmseg - INFO - Iter [1050/4320]	lr: 7.807e-03, eta: 0:29:28, time: 0.533, data_time: 0.010, memory: 13224, decode.loss_ce: 0.3239, decode.acc_seg: 85.3482, aux.loss_ce: 0.1799, aux.acc_seg: 79.4532, loss: 0.5038
# 2022-11-05 15:50:44,458 - mmseg - INFO - Iter [1100/4320]	lr: 7.701e-03, eta: 0:29:00, time: 0.531, data_time: 0.007, memory: 13224, decode.loss_ce: 0.3468, decode.acc_seg: 83.3408, aux.loss_ce: 0.1808, aux.acc_seg: 79.1062, loss: 0.5277
# 2022-11-05 15:51:11,105 - mmseg - INFO - Iter [1150/4320]	lr: 7.595e-03, eta: 0:28:32, time: 0.533, data_time: 0.008, memory: 13224, decode.loss_ce: 0.2985, decode.acc_seg: 86.2934, aux.loss_ce: 0.1686, aux.acc_seg: 80.7130, loss: 0.4671
# 2022-11-05 15:51:37,841 - mmseg - INFO - Iter [1200/4320]	lr: 7.489e-03, eta: 0:28:04, time: 0.535, data_time: 0.009, memory: 13224, decode.loss_ce: 0.3293, decode.acc_seg: 84.5687, aux.loss_ce: 0.1711, aux.acc_seg: 80.1402, loss: 0.5005
# 2022-11-05 15:52:04,074 - mmseg - INFO - Iter [1250/4320]	lr: 7.382e-03, eta: 0:27:35, time: 0.525, data_time: 0.008, memory: 13224, decode.loss_ce: 0.3399, decode.acc_seg: 83.6781, aux.loss_ce: 0.1741, aux.acc_seg: 80.0471, loss: 0.5140
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>] 2016/2016, 37.5 task/s, elapsed: 54s, ETA:     0s2022-11-05 15:53:37,345 - mmseg - INFO - per class results:
# 2022-11-05 15:53:37,346 - mmseg - INFO -
# +--------------------+-------+-------+
# |       Class        |  IoU  |  Acc  |
# +--------------------+-------+-------+
# | impervious_surface | 78.62 | 84.77 |
# |      building      | 84.97 | 96.36 |
# |   low_vegetation   | 66.88 | 85.16 |
# |        tree        | 68.32 | 74.73 |
# |        car         | 85.06 | 88.25 |
# |      clutter       | 30.47 | 47.68 |
# +--------------------+-------+-------+
# 2022-11-05 15:53:37,347 - mmseg - INFO - Summary:
# 2022-11-05 15:53:37,347 - mmseg - INFO -
# +-------+-------+-------+
# |  aAcc |  mIoU |  mAcc |
# +-------+-------+-------+
# | 84.47 | 69.05 | 79.49 |
# +-------+-------+-------+
# 2022-11-05 15:53:37,347 - mmseg - INFO - Iter(val) [2016]	aAcc: 0.8447, mIoU: 0.6905, mAcc: 0.7949, IoU.impervious_surface: 0.7862, IoU.building: 0.8497, IoU.low_vegetation: 0.6688, IoU.tree: 0.6832, IoU.car: 0.8506, IoU.clutter: 0.3047, Acc.impervious_surface: 0.8477, Acc.building: 0.9636, Acc.low_vegetation: 0.8516, Acc.tree: 0.7473, Acc.car: 0.8825, Acc.clutter: 0.4768
# 2022-11-05 15:53:42,432 - mmseg - INFO - Iter [1300/4320]	lr: 7.275e-03, eta: 0:28:32, time: 1.260, data_time: 0.720, memory: 13224, decode.loss_ce: 0.4098, decode.acc_seg: 83.5765, aux.loss_ce: 0.2196, aux.acc_seg: 78.2665, loss: 0.6294
# 2022-11-05 16:01:50,881 - mmseg - INFO - Iter [2100/4320]	lr: 5.540e-03, eta: 0:20:28, time: 0.522, data_time: 0.007, memory: 13224, decode.loss_ce: 0.2568, decode.acc_seg: 87.8219, aux.loss_ce: 0.1436, aux.acc_seg: 83.3792, loss: 0.4004
# 2022-11-05 16:02:17,428 - mmseg - INFO - Iter [2150/4320]	lr: 5.430e-03, eta: 0:19:59, time: 0.531, data_time: 0.011, memory: 13224, decode.loss_ce: 0.2426, decode.acc_seg: 88.9934, aux.loss_ce: 0.1361, aux.acc_seg: 84.9655, loss: 0.3787
# 2022-11-05 16:02:22,581 - mmseg - INFO - Saving checkpoint at 5 epochs
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>] 2016/2016, 36.6 task/s, elapsed: 55s, ETA:     0s2022-11-05 16:03:36,313 - mmseg - INFO - per class results:
# 2022-11-05 16:03:36,314 - mmseg - INFO -
# +--------------------+-------+-------+
# |       Class        |  IoU  |  Acc  |
# +--------------------+-------+-------+
# | impervious_surface |  84.3 | 91.06 |
# |      building      | 91.04 | 96.28 |
# |   low_vegetation   | 72.87 | 90.77 |
# |        tree        |  76.1 | 83.61 |
# |        car         | 88.97 | 93.37 |
# |      clutter       |  32.4 | 36.19 |
# +--------------------+-------+-------+
# 2022-11-05 16:03:36,314 - mmseg - INFO - Summary:
# 2022-11-05 16:03:36,314 - mmseg - INFO -
# +------+-------+-------+
# | aAcc |  mIoU |  mAcc |
# +------+-------+-------+
# | 88.7 | 74.28 | 81.88 |
# +------+-------+-------+
# 2022-11-05 16:03:36,314 - mmseg - INFO - Iter(val) [2016]	aAcc: 0.8870, mIoU: 0.7428, mAcc: 0.8188, IoU.impervious_surface: 0.8430, IoU.building: 0.9104, IoU.low_vegetation: 0.7287, IoU.tree: 0.7610, IoU.car: 0.8897, IoU.clutter: 0.3240, Acc.impervious_surface: 0.9106, Acc.building: 0.9628, Acc.low_vegetation: 0.9077, Acc.tree: 0.8361, Acc.car: 0.9337, Acc.clutter: 0.3619
# 2022-11-05 16:03:59,504 - mmseg - INFO - Iter [2200/4320]	lr: 5.319e-03, eta: 0:19:32, time: 0.579, data_time: 0.067, memory: 13224, decode.loss_ce: 0.2538, decode.acc_seg: 88.3710, aux.loss_ce: 0.1415, aux.acc_seg: 84.0721, loss: 0.3953
# 2022-11-05 16:04:25,706 - mmseg - INFO - Iter [2250/4320]	lr: 5.208e-03, eta: 0:19:03, time: 0.524, data_time: 0.009, memory: 13224, decode.loss_ce: 0.2464, decode.acc_seg: 87.9655, aux.loss_ce: 0.1421, aux.acc_seg: 83.6271, loss: 0.3885
# 2022-11-05 16:04:51,811 - mmseg - INFO - Iter [2300/4320]	lr: 5.097e-03, eta: 0:18:34, time: 0.522, data_time: 0.007, memory: 13224, decode.loss_ce: 0.2329, decode.acc_seg: 89.3464, aux.loss_ce: 0.1376, aux.acc_seg: 84.7869, loss: 0.3706
# 2022-11-05 16:05:18,028 - mmseg - INFO - Iter [2350/4320]	lr: 4.986e-03, eta: 0:18:06, time: 0.524, data_time: 0.008, memory: 13224, decode.loss_ce: 0.2474, decode.acc_seg: 88.1474, aux.loss_ce: 0.1326, aux.acc_seg: 84.7523, loss: 0.3800
# 2022-11-05 16:05:44,194 - mmseg - INFO - Iter [2400/4320]	lr: 4.874e-03, eta: 0:17:37, time: 0.523, data_time: 0.007, memory: 13224, decode.loss_ce: 0.2215, decode.acc_seg: 89.2885, aux.loss_ce: 0.1246, aux.acc_seg: 85.6509, loss: 0.3461
# 2022-11-05 16:06:10,393 - mmseg - INFO - Iter [2450/4320]	lr: 4.762e-03, eta: 0:17:08, time: 0.524, data_time: 0.007, memory: 13224, decode.loss_ce: 0.2354, decode.acc_seg: 89.0215, aux.loss_ce: 0.1341, aux.acc_seg: 84.8238, loss: 0.3696
# 2022-11-05 16:06:36,720 - mmseg - INFO - Iter [2500/4320]	lr: 4.650e-03, eta: 0:16:40, time: 0.527, data_time: 0.008, memory: 13224, decode.loss_ce: 0.2333, decode.acc_seg: 88.9129, aux.loss_ce: 0.1313, aux.acc_seg: 84.5605, loss: 0.3646
# 2022-11-05 16:07:03,050 - mmseg - INFO - Iter [2550/4320]	lr: 4.537e-03, eta: 0:16:12, time: 0.527, data_time: 0.009, memory: 13224, decode.loss_ce: 0.2347, decode.acc_seg: 88.9965, aux.loss_ce: 0.1271, aux.acc_seg: 85.5813, loss: 0.3618
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>] 2016/2016, 38.7 task/s, elapsed: 52s, ETA:     0s2022-11-05 16:08:32,232 - mmseg - INFO - per class results:
# 2022-11-05 16:08:32,232 - mmseg - INFO -
# +--------------------+-------+-------+
# |       Class        |  IoU  |  Acc  |
# +--------------------+-------+-------+
# | impervious_surface |  84.9 | 91.56 |
# |      building      | 91.81 | 96.78 |
# |   low_vegetation   | 74.26 | 86.22 |
# |        tree        | 77.06 | 85.44 |
# |        car         | 89.22 | 92.49 |
# |      clutter       | 40.39 | 56.55 |
# +--------------------+-------+-------+
# 2022-11-05 16:08:32,232 - mmseg - INFO - Summary:
# 2022-11-05 16:08:32,232 - mmseg - INFO -
# +-------+-------+-------+
# |  aAcc |  mIoU |  mAcc |
# +-------+-------+-------+
# | 89.22 | 76.27 | 84.84 |
# +-------+-------+-------+
# 2022-11-05 16:08:32,233 - mmseg - INFO - Iter(val) [2016]	aAcc: 0.8922, mIoU: 0.7627, mAcc: 0.8484, IoU.impervious_surface: 0.8490, IoU.building: 0.9181, IoU.low_vegetation: 0.7426, IoU.tree: 0.7706, IoU.car: 0.8922, IoU.clutter: 0.4039, Acc.impervious_surface: 0.9156, Acc.building: 0.9678, Acc.low_vegetation: 0.8622, Acc.tree: 0.8544, Acc.car: 0.9249, Acc.clutter: 0.5655
# 2022-11-05 16:08:38,853 - mmseg - INFO - Iter [2600/4320]	lr: 4.424e-03, eta: 0:15:53, time: 0.822, data_time: 0.316, memory: 13224, decode.loss_ce: 0.2439, decode.acc_seg: 87.9270, aux.loss_ce: 0.1398, aux.acc_seg: 83.5485, loss: 0.3837
# 2022-11-05 16:09:04,847 - mmseg - INFO - Iter [2650/4320]	lr: 4.311e-03, eta: 0:15:25, time: 0.520, data_time: 0.007, memory: 13224, decode.loss_ce: 0.2133, decode.acc_seg: 89.9626, aux.loss_ce: 0.1202, aux.acc_seg: 86.4715, loss: 0.3335
# 2022-11-05 16:09:30,877 - mmseg - INFO - Iter [2700/4320]	lr: 4.197e-03, eta: 0:14:56, time: 0.521, data_time: 0.007, memory: 13224, decode.loss_ce: 0.2343, decode.acc_seg: 89.1810, aux.loss_ce: 0.1345, aux.acc_seg: 84.7924, loss: 0.3689
# 2022-11-05 16:09:57,331 - mmseg - INFO - Iter [2750/4320]	lr: 4.083e-03, eta: 0:14:27, time: 0.529, data_time: 0.010, memory: 13224, decode.loss_ce: 0.2224, decode.acc_seg: 89.3150, aux.loss_ce: 0.1289, aux.acc_seg: 85.1963, loss: 0.3513
# 2022-11-05 16:10:23,495 - mmseg - INFO - Iter [2800/4320]	lr: 3.969e-03, eta: 0:13:59, time: 0.523, data_time: 0.007, memory: 13224, decode.loss_ce: 0.2611, decode.acc_seg: 88.0465, aux.loss_ce: 0.1396, aux.acc_seg: 84.5787, loss: 0.4007
# 2022-11-05 16:11:16,005 - mmseg - INFO - Iter [2900/4320]	lr: 3.739e-03, eta: 0:13:02, time: 0.524, data_time: 0.008, memory: 13224, decode.loss_ce: 0.2251, decode.acc_seg: 89.5442, aux.loss_ce: 0.1269, aux.acc_seg: 85.6250, loss: 0.3519
# 2022-11-05 16:12:08,416 - mmseg - INFO - Exp name: pspnet_r50-d8_512x512_160k_ade20k.py
# 2022-11-05 16:12:08,416 - mmseg - INFO - Iter [3000/4320]	lr: 3.508e-03, eta: 0:12:06, time: 0.523, data_time: 0.007, memory: 13224, decode.loss_ce: 0.2252, decode.acc_seg: 89.3836, aux.loss_ce: 0.1275, aux.acc_seg: 85.4089, loss: 0.3527
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>] 2016/2016, 35.8 task/s, elapsed: 56s, ETA:     0s2022-11-05 16:13:29,764 - mmseg - INFO - per class results:
# 2022-11-05 16:13:29,765 - mmseg - INFO -
# +--------------------+-------+-------+
# |       Class        |  IoU  |  Acc  |
# +--------------------+-------+-------+
# | impervious_surface | 84.96 | 92.04 |
# |      building      | 90.76 | 97.44 |
# |   low_vegetation   | 73.96 | 87.37 |
# |        tree        | 77.02 |  85.4 |
# |        car         | 89.62 | 93.93 |
# |      clutter       |  37.8 | 43.43 |
# +--------------------+-------+-------+
# 2022-11-05 16:13:29,765 - mmseg - INFO - Summary:
# 2022-11-05 16:13:29,765 - mmseg - INFO -
# +-------+-------+-------+
# |  aAcc |  mIoU |  mAcc |
# +-------+-------+-------+
# | 89.23 | 75.69 | 83.27 |
# +-------+-------+-------+
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>] 2016/2016, 38.6 task/s, elapsed: 52s, ETA:     0s2022-11-05 16:18:27,471 - mmseg - INFO - per class results:
# 2022-11-05 16:18:27,471 - mmseg - INFO -
# +--------------------+-------+-------+
# |       Class        |  IoU  |  Acc  |
# +--------------------+-------+-------+
# | impervious_surface | 85.26 | 93.65 |
# |      building      | 91.72 |  97.5 |
# |   low_vegetation   | 75.22 | 87.51 |
# |        tree        | 77.48 | 84.58 |
# |        car         | 88.87 | 92.47 |
# |      clutter       | 38.96 | 44.94 |
# +--------------------+-------+-------+
# 2022-11-05 16:18:27,472 - mmseg - INFO - Summary:
# 2022-11-05 16:18:27,472 - mmseg - INFO -
# +-------+-------+-------+
# |  aAcc |  mIoU |  mAcc |
# +-------+-------+-------+
# | 89.67 | 76.25 | 83.44 |
# +-------+-------+-------+
# 2022-11-05 16:18:27,472 - mmseg - INFO - Iter(val) [2016]	aAcc: 0.8967, mIoU: 0.7625, mAcc: 0.8344, IoU.impervious_surface: 0.8526, IoU.building: 0.9172, IoU.low_vegetation: 0.7522, IoU.tree: 0.7748, IoU.car: 0.8887, IoU.clutter: 0.3896, Acc.impervious_surface: 0.9365, Acc.building: 0.9750, Acc.low_vegetation: 0.8751, Acc.tree: 0.8458, Acc.car: 0.9247, Acc.clutter: 0.4494
# 2022-11-05 16:18:53,090 - mmseg - INFO - Iter [3500/4320]	lr: 2.321e-03, eta: 0:07:30, time: 0.581, data_time: 0.067, memory: 13224, decode.loss_ce: 0.2111, decode.acc_seg: 90.4431, aux.loss_ce: 0.1191, aux.acc_seg: 86.4355, loss: 0.3302
# 2022-11-05 16:19:19,143 - mmseg - INFO - Iter [3550/4320]	lr: 2.199e-03, eta: 0:07:02, time: 0.521, data_time: 0.007, memory: 13224, decode.loss_ce: 0.2038, decode.acc_seg: 90.4118, aux.loss_ce: 0.1236, aux.acc_seg: 86.1558, loss: 0.3274
# 2022-11-05 16:19:45,385 - mmseg - INFO - Iter [3600/4320]	lr: 2.076e-03, eta: 0:06:34, time: 0.525, data_time: 0.008, memory: 13224, decode.loss_ce: 0.2055, decode.acc_seg: 90.7130, aux.loss_ce: 0.1203, aux.acc_seg: 86.8891, loss: 0.3258
# 2022-11-05 16:20:11,571 - mmseg - INFO - Iter [3650/4320]	lr: 1.952e-03, eta: 0:06:07, time: 0.524, data_time: 0.008, memory: 13224, decode.loss_ce: 0.1857, decode.acc_seg: 91.3420, aux.loss_ce: 0.1102, aux.acc_seg: 87.4291, loss: 0.2959
# 2022-11-05 16:20:37,801 - mmseg - INFO - Iter [3700/4320]	lr: 1.828e-03, eta: 0:05:39, time: 0.525, data_time: 0.008, memory: 13224, decode.loss_ce: 0.1992, decode.acc_seg: 90.7438, aux.loss_ce: 0.1238, aux.acc_seg: 86.1750, loss: 0.3230
# 2022-11-05 16:21:03,936 - mmseg - INFO - Iter [3750/4320]	lr: 1.702e-03, eta: 0:05:12, time: 0.523, data_time: 0.007, memory: 13224, decode.loss_ce: 0.1844, decode.acc_seg: 91.0447, aux.loss_ce: 0.1053, aux.acc_seg: 87.7286, loss: 0.2897
# 2022-11-05 16:21:30,158 - mmseg - INFO - Iter [3800/4320]	lr: 1.575e-03, eta: 0:04:44, time: 0.524, data_time: 0.008, memory: 13224, decode.loss_ce: 0.1817, decode.acc_seg: 91.4771, aux.loss_ce: 0.1088, aux.acc_seg: 87.6359, loss: 0.2904
# 2022-11-05 16:21:56,339 - mmseg - INFO - Iter [3850/4320]	lr: 1.447e-03, eta: 0:04:16, time: 0.524, data_time: 0.008, memory: 13224, decode.loss_ce: 0.1793, decode.acc_seg: 91.2145, aux.loss_ce: 0.1116, aux.acc_seg: 86.6182, loss: 0.2909
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>] 2016/2016, 37.5 task/s, elapsed: 54s, ETA:     0s2022-11-05 16:23:23,259 - mmseg - INFO - per class results:
# 2022-11-05 16:23:23,260 - mmseg - INFO -
# +--------------------+-------+-------+
# |       Class        |  IoU  |  Acc  |
# +--------------------+-------+-------+
# | impervious_surface | 85.52 | 92.06 |
# |      building      | 92.15 | 97.07 |
# |   low_vegetation   | 75.37 |  90.3 |
# |        tree        | 77.33 | 84.07 |
# |        car         | 90.07 | 94.03 |
# |      clutter       | 41.17 |  49.3 |
# +--------------------+-------+-------+
# 2022-11-05 16:23:23,260 - mmseg - INFO - Summary:
# 2022-11-05 16:23:23,260 - mmseg - INFO -
# +-------+-------+-------+
# |  aAcc |  mIoU |  mAcc |
# +-------+-------+-------+
# | 89.77 | 76.93 | 84.47 |
# +-------+-------+-------+
# 2022-11-05 16:23:23,261 - mmseg - INFO - Iter(val) [2016]	aAcc: 0.8977, mIoU: 0.7693, mAcc: 0.8447, IoU.impervious_surface: 0.8552, IoU.building: 0.9215, IoU.low_vegetation: 0.7537, IoU.tree: 0.7733, IoU.car: 0.9007, IoU.clutter: 0.4117, Acc.impervious_surface: 0.9206, Acc.building: 0.9707, Acc.low_vegetation: 0.9030, Acc.tree: 0.8407, Acc.car: 0.9403, Acc.clutter: 0.4930
# 2022-11-05 16:23:32,143 - mmseg - INFO - Iter [3900/4320]	lr: 1.318e-03, eta: 0:03:50, time: 0.736, data_time: 0.213, memory: 13224, decode.loss_ce: 0.1653, decode.acc_seg: 91.6033, aux.loss_ce: 0.1085, aux.acc_seg: 87.3390, loss: 0.2738
# 2022-11-05 16:23:58,205 - mmseg - INFO - Iter [3950/4320]	lr: 1.187e-03, eta: 0:03:23, time: 0.521, data_time: 0.007, memory: 13224, decode.loss_ce: 0.1955, decode.acc_seg: 90.9646, aux.loss_ce: 0.1148, aux.acc_seg: 87.1172, loss: 0.3103
# 2022-11-05 16:24:24,347 - mmseg - INFO - Exp name: pspnet_r50-d8_512x512_160k_ade20k.py
# 2022-11-05 16:24:24,348 - mmseg - INFO - Iter [4000/4320]	lr: 1.054e-03, eta: 0:02:55, time: 0.523, data_time: 0.008, memory: 13224, decode.loss_ce: 0.1841, decode.acc_seg: 91.2544, aux.loss_ce: 0.1122, aux.acc_seg: 87.5155, loss: 0.2963
# 2022-11-05 16:24:50,625 - mmseg - INFO - Iter [4050/4320]	lr: 9.192e-04, eta: 0:02:28, time: 0.526, data_time: 0.008, memory: 13224, decode.loss_ce: 0.1835, decode.acc_seg: 91.1508, aux.loss_ce: 0.1068, aux.acc_seg: 87.2408, loss: 0.2903
# 2022-11-05 16:25:16,912 - mmseg - INFO - Iter [4100/4320]	lr: 7.818e-04, eta: 0:02:00, time: 0.526, data_time: 0.009, memory: 13224, decode.loss_ce: 0.1856, decode.acc_seg: 91.7020, aux.loss_ce: 0.1063, aux.acc_seg: 88.1242, loss: 0.2919
# 2022-11-05 16:25:43,373 - mmseg - INFO - Iter [4150/4320]	lr: 6.412e-04, eta: 0:01:33, time: 0.529, data_time: 0.009, memory: 13224, decode.loss_ce: 0.1831, decode.acc_seg: 91.1583, aux.loss_ce: 0.1117, aux.acc_seg: 87.6127, loss: 0.2947
# 2022-11-05 16:26:09,553 - mmseg - INFO - Iter [4200/4320]	lr: 4.965e-04, eta: 0:01:05, time: 0.524, data_time: 0.007, memory: 13224, decode.loss_ce: 0.1884, decode.acc_seg: 91.0712, aux.loss_ce: 0.1087, aux.acc_seg: 87.6573, loss: 0.2971
# 2022-11-05 16:26:35,721 - mmseg - INFO - Iter [4250/4320]	lr: 3.454e-04, eta: 0:00:38, time: 0.523, data_time: 0.007, memory: 13224, decode.loss_ce: 0.1795, decode.acc_seg: 91.2923, aux.loss_ce: 0.1078, aux.acc_seg: 87.2491, loss: 0.2873
# 2022-11-05 16:27:02,113 - mmseg - INFO - Iter [4300/4320]	lr: 1.820e-04, eta: 0:00:10, time: 0.528, data_time: 0.009, memory: 13224, decode.loss_ce: 0.1793, decode.acc_seg: 91.6721, aux.loss_ce: 0.1036, aux.acc_seg: 88.2435, loss: 0.2829
# 2022-11-05 16:27:12,526 - mmseg - INFO - Saving checkpoint at 10 epochs
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>] 2016/2016, 36.5 task/s, elapsed: 55s, ETA:     0s2022-11-05 16:28:22,692 - mmseg - INFO - per class results:
# 2022-11-05 16:28:22,693 - mmseg - INFO -
# +--------------------+-------+-------+
# |       Class        |  IoU  |  Acc  |
# +--------------------+-------+-------+
# | impervious_surface | 85.74 | 92.84 |
# |      building      | 92.02 | 97.22 |
# |   low_vegetation   | 75.62 | 88.78 |
# |        tree        | 77.93 | 85.32 |
# |        car         | 90.02 | 94.06 |
# |      clutter       | 40.09 | 47.68 |
# +--------------------+-------+-------+
# 2022-11-05 16:28:22,693 - mmseg - INFO - Summary:
# 2022-11-05 16:28:22,693 - mmseg - INFO -
# +-------+------+-------+
# |  aAcc | mIoU |  mAcc |
# +-------+------+-------+
# | 89.88 | 76.9 | 84.32 |
# +-------+------+-------+
# 2022-11-05 16:28:22,694 - mmseg - INFO - Iter(val) [2016]	aAcc: 0.8988, mIoU: 0.7690, mAcc: 0.8432, IoU.impervious_surface: 0.8574, IoU.building: 0.9202, IoU.low_vegetation: 0.7562, IoU.tree: 0.7793, IoU.car: 0.9002, IoU.clutter: 0.4009, Acc.impervious_surface: 0.9284, Acc.building: 0.9722, Acc.low_vegetation: 0.8878, Acc.tree: 0.8532, Acc.car: 0.9406, Acc.clutter: 0.4768

# %%
# !python tools/test.py configs/pspnet/pspnet_r50-d8_512x512_160k_ade20k.py work_dirs/pspnet_r50-d8_512x512_160k_ade20k/latest.pth --opacity 1 --eval mIoU --show-dir out
# Out:
# 2022-11-05 16:29:29,016 - mmseg - INFO - Multi-processing start method is `None`
# 2022-11-05 16:29:29,019 - mmseg - INFO - OpenCV num_threads is `32
# 2022-11-05 16:29:29,118 - mmseg - INFO - Loaded 2016 images
# /home/rongjian/yolov7-main/wandb/mmsegmentation-master/mmseg/models/losses/cross_entropy_loss.py:236: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   'Default ``avg_non_ignore`` is False, if you would like to '
# load checkpoint from local path: work_dirs/pspnet_r50-d8_512x512_160k_ade20k/latest.pth
# tools/test.py:265: UserWarning: SyncBN is only supported with DDP. To be compatible with DP, we convert SyncBN to BN. Please use dist_train.sh which can avoid this error.
#   'SyncBN is only supported with DDP. To be compatible with DP, '
# [>>>>>>>>>>>>>>>>>>>>>>>>>>] 2016/2016, 13.4 task/s, elapsed: 150s, ETA:     0sper class results:
#
# +--------------------+-------+-------+
# |       Class        |  IoU  |  Acc  |
# +--------------------+-------+-------+
# | impervious_surface | 85.73 | 92.84 |
# |      building      | 92.02 | 97.22 |
# |   low_vegetation   | 75.62 | 88.78 |
# |        tree        | 77.93 | 85.32 |
# |        car         | 90.02 | 94.06 |
# |      clutter       | 40.09 | 47.68 |
# +--------------------+-------+-------+
# Summary:
#
# +-------+------+-------+
# |  aAcc | mIoU |  mAcc |
# +-------+------+-------+
# | 89.88 | 76.9 | 84.32 |
# +-------+------+-------+

# %%
import cv2
import matplotlib.pyplot as plt
import os
path = '/home/rongjian/yolov7-main/wandb/img_dir/val'
files = os.listdir(path)
# 使用matplotlib展示多张图片
num = len(files)
j = 0
while j<20:
    
    for i in range(0,3):
        if i==2:
            img = cv2.imread('/home/rongjian/yolov7-main/wandb/mmsegmentation-master/out'+'/'+files[j])
            title="predict"
        #行，列，索引
            plt.subplot(1,3,i+1)
        #plt.figure(figsize=(2, 2))
            plt.imshow(img)
            plt.title(title,fontsize=8)
            plt.xticks([])
            plt.yticks([])
    
        elif i==1:
            img = cv2.imread('/home/rongjian/yolov7-main/wandb/ann_dir/val'+'/'+files[j])
            title="ground ture"
        #行，列，索引
            plt.subplot(1,3,i+1)
            #plt.figure(figsize=(2,2))
            plt.imshow(img)
            plt.title(title,fontsize=8)
            plt.xticks([])
            plt.yticks([])
        elif i==0:
            img = cv2.imread('/home/rongjian/yolov7-main/wandb/img_dir/val'+'/'+files[j])
            title="image"
        #行，列，索引
            plt.subplot(1,3,i+1)
            #plt.figure(figsize=(2, 2))
            plt.imshow(img)
            plt.title(title,fontsize=8)
            plt.xticks([])
            plt.yticks([])   
    plt.show()
    j = j+1
